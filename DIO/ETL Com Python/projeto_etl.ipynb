# %%
# Curso - Fundamentos de ETL com Python - Digital Innovation One
# 10.05.22 - 21h45

# %%
# Importando a biblioteca pandas
# pd - alias da biblioteca pandas 
import pandas as pd

# %%
# Carregando o arquivo csv atraves do método read_csv (arquivo informado como parametro)
# funcao read_csv retorna um novo objeto de dados
dados = pd.read_csv('ocorrencia.csv')

# %%
# Saída do objeto de dados gerado a partir da leitura do csv.
dados
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 52242               52242               52242
# 1                 45331               45331               45331
# 2                 45333               45333               45333
# 3                 45401               45401               45401
# 4                 45407               45407               45407
# ...                 ...                 ...                 ...
# 5162              80458               80458               80458
# 5163              80452               80452               80452
# 5164              80457               80457               80457
# 5165              80460               80460               80460
# 5166              80467               80467               80467
#
#      ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      PORTO ALEGRE            RS
# 1                    ACIDENTE         GUARULHOS            SP
# ...
